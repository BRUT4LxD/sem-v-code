# %%
import fiftyone as fo
# Out:
# Migrating database to v0.19.0

# %%
session = fo.launch_app()
# Out:
# <style>
# @import url("https://fonts.googleapis.com/css2?family=Palanquin&display=swap");
#
# body, html {
#   margin: 0;
#   padding: 0;
#   width: 100%;
# }
#
# #focontainer-1fc943f8-8860-420a-b664-283e2b3b09a5 {
#   position: relative;
#   height: 800px;
#   display: block !important;
# }
# #foactivate-1fc943f8-8860-420a-b664-283e2b3b09a5 {
#   font-weight: bold;
#   cursor: pointer;
#   font-size: 24px;
#   border-radius: 3px;
#   text-align: center;
#   padding: 0.5em;
#   color: rgb(255, 255, 255);
#   font-family: "Palanquin", sans-serif;
#   position: absolute;
#   left: 50%;
#   top: 50%;
#   width: 160px;
#   margin-left: -80px;
#   margin-top: -23px;
#   background: hsla(210,11%,15%, 0.8);
#   border: none;
# }
# #foactivate-1fc943f8-8860-420a-b664-283e2b3b09a5:focus {
#   outline: none;
# }
# #fooverlay-1fc943f8-8860-420a-b664-283e2b3b09a5 {
#   width: 100%;
#   height: 100%;
#   background: hsla(208, 7%, 46%, 0.7);
#   position: absolute;
#   top: 0;
#   left: 0;
# ...

# %%
dataset = fo.Dataset("my-d")

# %%
session = fo.launch_app(dataset)
# Out:
#         <iframe
#             width="100%"
#             height="800"
#             src="http://localhost:5151/?notebook=True&subscription=f3bc6d8c-5891-451d-9a9a-15939c2adc00"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
